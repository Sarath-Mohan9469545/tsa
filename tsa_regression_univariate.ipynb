# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarath-Mohan9469545/tsa/blob/main/tsa_regression_univariate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("/content/tunnel.csv")
df
# Out:
#             Day  NumVehicles
# 0    2003-11-01       103536
# 1    2003-11-02        92051
# 2    2003-11-03       100795
# 3    2003-11-04       102352
# 4    2003-11-05       106569
# ..          ...          ...
# 742  2005-11-12       104646
# 743  2005-11-13        94424
# 744  2005-11-14       112165
# 745  2005-11-15       114296
# 746  2005-11-16       114690
#
# [747 rows x 2 columns]

# %%
from datetime import datetime as dt
y=df[["NumVehicles"]]
x=df[["Day"]]

# %%
x= pd.to_datetime(x.iloc[:, 0], infer_datetime_format=True)

# %%
x
# Out:
# 0     2003-11-01
# 1     2003-11-02
# 2     2003-11-03
# 3     2003-11-04
# 4     2003-11-05
#          ...
# 742   2005-11-12
# 743   2005-11-13
# 744   2005-11-14
# 745   2005-11-15
# 746   2005-11-16
# Name: Day, Length: 747, dtype: datetime64[ns]

# %%
plt.rcParams["figure.figsize"] = (15,5.5)
plt.plot(x,y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
x_train= np.array([i for i in range(747)]).reshape(-1,1)
y_train=y.values.reshape(-1,1)
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_train)

# %%
plt.plot(x,y_pred)
plt.plot(x,y)

# %%
df2=pd.read_csv("/content/us-retail-sales.csv")
df2
# Out:
#        Month  Clothing  Appliances  FoodAndBeverage  Automobiles  \
# 0    1992-01      6938        3657            29589        26788
# 1    1992-02      7524        3490            28570        28203
# 2    1992-03      8475        3669            29682        31684
# 3    1992-04      9401        3527            30228        32547
# 4    1992-05      9558        3571            31677        32883
# ..       ...       ...         ...              ...          ...
# 331  2019-08     23829        7519            66937       105884
# 332  2019-09     19567        7123            62420        91758
# 333  2019-10     21400        7096            64849        95219
# 334  2019-11     25170        9242            66363        93303
# 335  2019-12     35157       10886            70028        96137
#
#      GeneralMerchandise  BuildingMaterials
# 0                 14996               8964
# 1                 16015               9023
# 2                 17984              10608
# ...

# %%
y_clothes=df2[["Clothing"]]
y_food=df2[["FoodAndBeverage"]]

# %%
xdf2=df2[["Month"]]

# %%
xdf2= pd.to_datetime(xdf2.iloc[:, 0], infer_datetime_format=True)

# %%
plt.plot(xdf2,y_clothes)
plt.show()

# %%
model2 = LinearRegression()
x_train2= np.array([i for i in range(336)]).reshape(-1,1)
y_train2=y_clothes.values.reshape(-1,1)
model2.fit(x_train2, y_train2)
# Out:
# LinearRegression()

# %%
y_pred2=model2.predict(x_train2)

# %%
plt.plot(xdf2,y_pred2)
plt.plot(xdf2,y_clothes)
plt.show()

# %%
plt.plot(xdf2,y_food)
plt.show()

# %%
model3 = LinearRegression()
x_train3= np.array([i for i in range(336)]).reshape(-1,1)
y_train3=y_food.values.reshape(-1,1)
model3.fit(x_train3, y_train3)
# Out:
# LinearRegression()

# %%
y_pred3=model3.predict(x_train3)

# %%
plt.plot(xdf2,y_pred3)
plt.plot(xdf2,y_food)
plt.show()
